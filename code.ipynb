# %%
import pandas as pd
import numpy as np 
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv(r'train.csv')

# %%
df
# Out:
#             id  annual_income  ...  grade_subgrade  loan_paid_back
# 0            0       29367.99  ...              C3             1.0
# 1            1       22108.02  ...              D3             0.0
# 2            2       49566.20  ...              C5             1.0
# 3            3       46858.25  ...              F1             1.0
# 4            4       25496.70  ...              D1             1.0
# ...        ...            ...  ...             ...             ...
# 593989  593989       23004.26  ...              C3             1.0
# 593990  593990       35289.43  ...              F5             1.0
# 593991  593991       47112.64  ...              C1             1.0
# 593992  593992       76748.44  ...              B2             1.0
# 593993  593993       48959.52  ...              B3             1.0
#
# [593994 rows x 13 columns]
