# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score,confusion_matrix
from xgboost import XGBClassifier

# %%
df = pd.read_csv(r'train.csv')

# %%
df = df.drop(columns=['id'])

# %%
print(df['loan_purpose'].unique())
print(df['employment_status'].unique())
print(df['education_level'].unique())
# Out:
# ['Other' 'Debt consolidation' 'Home' 'Education' 'Vacation' 'Car'
#  'Medical' 'Business']
# ['Self-employed' 'Employed' 'Unemployed' 'Retired' 'Student']
# ['High School' "Master's" "Bachelor's" 'PhD' 'Other']

# %%
df.isnull().sum()
# Out:
# annual_income           0
# debt_to_income_ratio    0
# credit_score            0
# loan_amount             0
# interest_rate           0
# gender                  0
# marital_status          0
# education_level         0
# employment_status       0
# loan_purpose            0
# grade_subgrade          0
# loan_paid_back          0
# dtype: int64

# %%
x = df.drop(columns=['loan_paid_back'])
y = df['loan_paid_back']

# %%
x_tr, x_tst, y_tr,y_tst = train_test_split(x,y,random_state= 42, test_size=0.2)

# %%
df.columns
# Out:
# Index(['annual_income', 'debt_to_income_ratio', 'credit_score', 'loan_amount',
#        'interest_rate', 'gender', 'marital_status', 'education_level',
#        'employment_status', 'loan_purpose', 'grade_subgrade',
#        'loan_paid_back'],
#       dtype='object')

# %%
trf1 =ColumnTransformer(transfromers =[
        ('Scaler', StandardScaler(),['credit_score','debt_to_income_ratio','annual_income','interest_rate','loan_amount']),
        ("OHE", OneHotEncoder(),['marital_status'])
])
